# %% [markdown]
# # Polymorphism
# The term polymorphism in the OOP language, refers to the ability of an object to adapt the code to the type of the data it is processing.
# In Python polymorphism is one of the key concepts and we can say that it is a built-in feature.
# Polymorphism is used in addition operator. We know that it is used extensively in Python programs. But it does not have a single use

# %%
# In integer
sum = 8+1
print("Integers are added:",sum)
# Out:
# Integers are added: 9

# %%
str1, str2 = "Python ","Programming"
conc = str1+str2
conc
# Out:
# 'Python Programming'

# %% [markdown]
# # Example 2:
# Using Length in different cases gives different output when working with different objects and data structures in Python

# %% [markdown]
# # Polymorphism through Inheritance - Method Overriding

# %%
from PIL import Image, ImageDraw, ImageFont
from IPython.display import display
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np

# %%
show_first_image = Image.open('Polymorphism through Inheritance.PNG')
display(show_first_image)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1360x705>

# %%
# Example
class Basic:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def display_data(self):
        print("In parent class display method.")
        print(self.name)
        print(self.age)
class Derived(Basic):
    def __init__(self, age, name, id):
        super().__init__(name,age)
        self.id = id
    def display_data(self):
        print("In Child class display method.")
        print(self.name)
        print(self.age)
        print(self.id)

# %%
first = Basic('John',28)
first.display_data()
# Out:
# In parent class display method.
# John
# 28

# %%
second = Derived('John',28,'E901')
second.display_data()
# Out:
# In Child class display method.
# 28
# John
# E901

# %%
image1 = Image.open(r'Polymorphism through Operator Overloading.PNG')
display(image1)
image2 = Image.open(r'Polymorphism through Operator Overloading 2.PNG')
display(image2)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1360x768>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1360x768>

# %% [markdown]
# # Magic Methods

# %%
image3 = Image.open(r'Magic Methods.PNG')
display(image3)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1360x768>

# %% [markdown]
# Like arithimetic operators all the operators in python are invoking the magic methods
