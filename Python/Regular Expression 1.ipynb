# %%
from PIL import Image
from IPython.display import display

# %%
image1 = Image.open("RegEx1.png")
display(image1)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1360x768>

# %%
# Example 1
# Importing reg ex library
import re

# %%
# Defining search pattern
pattern = 'a....s$'
teststring1 = 'abacus'
result = re.match(pattern, teststring1)
if result:
    print('Search successful')
else:
    print('Search unsuccessful')
# Out:
# Search successful

# %%
# the above expression would print the else block even if I change the Case of the teststring1
teststring1 = 'Abacus'
result = re.match(pattern, teststring1)
if result:
    print('Search successful')
else:
    print('Search unsuccessful')
# Out:
# Search unsuccessful
