# %%
from PIL import Image, ImageDraw, ImageFont
from IPython.display import display
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np

# %%
image_one = Image.open("Exception 1.png")
image_two = Image.open("Exception 2.png")
display(image_one,image_two)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1360x768>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1360x768>

# %%
# Example
x = int(input("Enter the value of x."))
if x>5:
    raise Exception("X should not exceed the value 5")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[4], line 4
#       2 x = int(input("Enter the value of x."))
#       3 if x>5:
# ----> 4     raise Exception("X should not exceed the value 5")
#
# Exception: X should not exceed the value 5

# %%
image_three = Image.open(r'Assertion Error.PNG')
display(image_three)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1360x768>

# %%
# Example checking if we are working on linux
import sys
sys.platform
# Out:
# 'win32'

# %%
assert('linux' in sys.platform), "This code runs on linux."
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 assert('linux' in sys.platform), "This code runs on linux."
#
# AssertionError: This code runs on linux.

# %%
image_four = Image.open(r'Try and Except.PNG')
display(image_four)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1360x768>

# %% [markdown]
# # Example 1

# %%
def tryexcept():
    assert('linux' in sys.platform)
    print("This function works on Linux")

# %%
tryexcept()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 tryexcept()
#
# Cell In[14], line 2, in tryexcept()
#       1 def tryexcept():
# ----> 2     assert('linux' in sys.platform)
#       3     print("This does not work on windows")
#
# AssertionError:

# %%
try:
    tryexcept()
except:
    print("This function works on Linux")
# Out:
# This function works on Linux

# %%
display(Image.open("Try and Except 2.png"))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1360x768>

# %%
display(Image.open("Try and Except with Else.PNG"))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1360x768>

# %%
image_finally = Image.open(r'Try, Except,Else and Finally.PNG')
display(image_finally)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1360x768>
