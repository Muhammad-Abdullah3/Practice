# %% [markdown]
# # List comprehension
# List comprehension provides shorter syntax to create a list

# %%
# Example
comprehension1 = [num for num in range(10) if num%2==0]
comprehension1
# Out:
# [0, 2, 4, 6, 8]

# %%
from PIL import Image
from IPython.display import display

# %%
image_one = Image.open(r'Key Point of Comprehension.png')
display(image_one)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1360x768>
